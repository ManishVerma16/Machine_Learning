# %%
import math
import pandas_datareader as web

# %%
pip install pandas_datareader
# Out:
# Requirement already satisfied: pandas_datareader in c:\users\manishverma\appdata\local\programs\python\python39\lib\site-packages (0.9.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\manishverma\appdata\local\programs\python\python39\lib\site-packages (from pandas_datareader) (2.25.1)
# Requirement already satisfied: lxml in c:\users\manishverma\appdata\local\programs\python\python39\lib\site-packages (from pandas_datareader) (4.6.3)
# Requirement already satisfied: pandas>=0.23 in c:\users\manishverma\appdata\local\programs\python\python39\lib\site-packages (from pandas_datareader) (1.2.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\manishverma\appdata\roaming\python\python39\site-packages (from pandas>=0.23->pandas_datareader) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\manishverma\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.23->pandas_datareader) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\manishverma\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.23->pandas_datareader) (1.20.2)
# Requirement already satisfied: six>=1.5 in c:\users\manishverma\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas_datareader) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\manishverma\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\manishverma\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.19.0->pandas_datareader) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\manishverma\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.19.0->pandas_datareader) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\manishverma\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2020.12.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
import pandas as pd

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
from keras.models import Sequential
from keras.layer import Dense, LSTM
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-3d829e6b3b15> in <module>
# ----> 1 from keras.models import Sequential
#       2 from keras.layer import Dense, LSTM
#
# ModuleNotFoundError: No module named 'keras'

# %%
pip install keras
# Out:
# Collecting keras
#   Downloading Keras-2.4.3-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\manishverma\appdata\local\programs\python\python39\lib\site-packages (from keras) (1.20.2)
# Requirement already satisfied: scipy>=0.14 in c:\users\manishverma\appdata\local\programs\python\python39\lib\site-packages (from keras) (1.6.2)
# Collecting pyyaml
#   Downloading PyYAML-5.4.1-cp39-cp39-win_amd64.whl (213 kB)
# Collecting h5py
#   Downloading h5py-3.2.1-cp39-cp39-win_amd64.whl (2.8 MB)
# Installing collected packages: pyyaml, h5py, keras
# Successfully installed h5py-3.2.1 keras-2.4.3 pyyaml-5.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('fivethirtyeight')

# %%
df = web.DataReader('AAPL', data_source='yahoo', start='2012-01-01', end='2019-12-17')

# %%
df
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2012-01-03  14.732143  14.607143  14.621429  14.686786  302220800.0  12.629209
# 2012-01-04  14.810000  14.617143  14.642857  14.765714  260022000.0  12.697079
# 2012-01-05  14.948214  14.738214  14.819643  14.929643  271269600.0  12.838044
# 2012-01-06  15.098214  14.972143  14.991786  15.085714  318292800.0  12.972249
# 2012-01-09  15.276786  15.048214  15.196429  15.061786  394024400.0  12.951672
# ...               ...        ...        ...        ...          ...        ...
# 2019-12-11  67.775002  67.125000  67.202499  67.692497   78756800.0  66.899139
# 2019-12-12  68.139999  66.830002  66.945000  67.864998  137310400.0  67.069626
# 2019-12-13  68.824997  67.732498  67.864998  68.787498  133587600.0  67.981300
# 2019-12-16  70.197502  69.245003  69.250000  69.964996  128186000.0  69.144997
# 2019-12-17  70.442497  69.699997  69.892502  70.102501  114158400.0  69.280899
#
# [2003 rows x 6 columns]

# %%
df.shape
# Out:
# (2003, 6)

# %%
plt.figure(figsize=(16, 8))
plt.title('Close Price Histroy')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %%
data = df.filter(['Close'])

# %%
dataset = data.values

# %%
training_data_len = math.ceil( len(dataset) * 0.8)
training_data_len
# Out:
# 1603

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)
scaled_data
# Out:
# array([[0.01316509],
#        [0.01457063],
#        [0.01748985],
#        ...,
#        [0.97658263],
#        [0.99755134],
#        [1.        ]])
